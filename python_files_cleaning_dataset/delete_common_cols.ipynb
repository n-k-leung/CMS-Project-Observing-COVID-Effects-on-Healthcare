# %% [markdown]
# removing common cols in provider_benefit_service_amounts

# %%
import pandas as pd 
file_name = 'provider_benefit_service_amounts.csv'
df = pd.read_csv(file_name, low_memory=False)
df.drop(columns=['Tot_Benes', 'Tot_Srvcs'], inplace=True)
print("dropped!")
# Out:
# dropped!

# %%
df.to_csv(file_name, index=False)
print("updated!")
# Out:
# updated!
