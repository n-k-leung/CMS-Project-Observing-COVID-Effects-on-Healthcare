# %%
import pandas as pd

df = pd.read_csv("state_combined.csv")

# only want us state in this file
valid_states = {
    'AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA',
    'HI','ID','IL','IN','IA','KS','KY','LA','ME','MD',
    'MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ',
    'NM','NY','NC','ND','OH','OK','OR','PA','RI','SC',
    'SD','TN','TX','UT','VT','VA','WA','WV','WI','WY'
}

df_valid = df[df['Rndrng_Prvdr_State_Abrvtn'].isin(valid_states)]
df_valid.to_csv("state_combined.csv", index=False)

print("valid checked!")
# Out:
# valid checked!
